# %%
# !nvidia-smi
# Out:
# Mon Aug  3 10:01:58 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# %pip install -q sentence-transformers

# %%
# !python generate_embeddings.py \
    --input sec_10k_embedding_records.jsonl \
    --limit 100 \
    --batch-size 8
# Out:
# Model: Qwen/Qwen3-Embedding-0.6B
# Embedding records: 100
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json: 100% 349/349 [00:00<00:00, 1.50MB/s]
# config_sentence_transformers.json: 100% 215/215 [00:00<00:00, 1.00MB/s]
# README.md: 100% 17.2k/17.2k [00:00<00:00, 30.9MB/s]
# config.json: 100% 727/727 [00:00<00:00, 1.49MB/s]
#
# model.safetensors: downloading bytes:  12% 146M/1.19G [00:01<00:05, 204MB/s, 11.0MB/s  ]
# model.safetensors: downloading bytes:  28% 337M/1.19G [00:02<00:03, 215MB/s, 29.2MB/s  ]
# model.safetensors: downloading bytes:  35% 419M/1.19G [00:02<00:03, 217MB/s, 35.0MB/s  ] ]
# model.safetensors: downloading bytes:  51% 613M/1.19G [00:03<00:01, 307MB/s, 50.2MB/s  ] ]
# model.safetensors: downloading bytes:  64% 763M/1.19G [00:03<00:01, 229MB/s, 61.9MB/s  ] ]
# model.safetensors: downloading bytes:  74% 884M/1.19G [00:04<00:01, 240MB/s, 68.7MB/s  ] ]
# model.safetensors: downloading bytes:  77% 913M/1.19G [00:04<00:01, 202MB/s, 71.2MB/s  ] ]
# model.safetensors: downloading bytes:  84% 1.00G/1.19G [00:04<00:00, 249MB/s, 75.8MB/s  ]]
# model.safetensors: downloading bytes:  87% 1.04G/1.19G [00:05<00:00, 188MB/s, 79.1MB/s  ]]
# model.safetensors: reconstructing file:  91% 1.08G/1.19G [00:07<00:00, 121MB/s, 70.0MB/s  ]
# model.safetensors: downloading bytes: 100% 1.04G/1.04G [00:07<00:00, 137MB/s, 78.4MB/s  ] ]
# model.safetensors: reconstructing file: 100% 1.19G/1.19G [00:07<00:00, 157MB/s, 82.6MB/s  ]
# Loading weights: 100% 310/310 [00:01<00:00, 296.26it/s]
# tokenizer_config.json: 100% 9.71k/9.71k [00:00<00:00, 20.7MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 53.7MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 71.1MB/s]
#
# tokenizer.json: downloading bytes:  29% 3.33M/11.4M [00:00<00:01, 5.89MB/s, 16.1kB/s  ]
# tokenizer.json: downloading bytes: 100% 3.40M/3.40M [00:00<00:00, 4.43MB/s,  334kB/s  ]
# tokenizer.json: reconstructing file: 100% 11.4M/11.4M [00:00<00:00, 14.9MB/s, 1.12MB/s  ]
# config.json: 100% 313/313 [00:00<00:00, 1.73MB/s]
# Device: cuda:0
# Model dtype: torch.float16
# Maximum sequence length: 32768
# Batches: 100% 13/13 [00:05<00:00,  2.36it/s]
# Shape: (100, 1024)
# Dtype: float32
# Norms: min=0.99999994, mean=1.00000000, max=1.00000012
# Maximum norm deviation: 0.00000012
# Time: 5.5 s
# Smoke test passed. Embeddings were not saved.

# %%
# !python generate_embeddings.py \
    --input sec_10k_embedding_records.jsonl \
    --output qwen3_embedding_0_6b_records.npz \
    --checkpoint-dir qwen3_embedding_checkpoints \
    --batch-size 8
# Out:
# Model: Qwen/Qwen3-Embedding-0.6B
# Embedding records: 7110
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 310/310 [00:01<00:00, 302.73it/s]
# Device: cuda:0
# Model dtype: torch.float16
# Maximum sequence length: 32768
# ALLY: generating 786 embeddings
# Batches: 100% 99/99 [00:22<00:00,  4.32it/s]
# ALLY: checkpoint saved
# BAC: generating 900 embeddings
# Batches: 100% 113/113 [00:23<00:00,  4.72it/s]
# BAC: checkpoint saved
# C: generating 1015 embeddings
# Batches: 100% 127/127 [00:32<00:00,  3.95it/s]
# C: checkpoint saved
# GS: generating 1151 embeddings
# Batches: 100% 144/144 [00:32<00:00,  4.38it/s]
# GS: checkpoint saved
# JPM: generating 1423 embeddings
# Batches: 100% 178/178 [00:35<00:00,  4.96it/s]
# JPM: checkpoint saved
# LOB: generating 497 embeddings
# Batches: 100% 63/63 [00:14<00:00,  4.30it/s]
# LOB: checkpoint saved
# PNC: generating 628 embeddings
# Batches: 100% 79/79 [00:23<00:00,  3.42it/s]
# PNC: checkpoint saved
# TFC: generating 520 embeddings
# Batches: 100% 65/65 [00:18<00:00,  3.52it/s]
# TFC: checkpoint saved
# USB: generating 97 embeddings
# Batches: 100% 13/13 [00:04<00:00,  3.18it/s]
# USB: checkpoint saved
# WFC: generating 93 embeddings
# Batches: 100% 12/12 [00:02<00:00,  4.22it/s]
# WFC: checkpoint saved
# Shape: (7110, 1024)
# Norms: min=0.99999988, mean=1.00000000, max=1.00000012
# Time for this run: 211.2 s
# Saved: qwen3_embedding_0_6b_records.npz

# %%
from google.colab import drive
from pathlib import Path
import shutil

drive.mount("/content/drive")

source_path = Path("/content/qwen3_embedding_0_6b_records.npz")
drive_path = Path(
    "/content/drive/MyDrive/qwen3_embedding_0_6b_records.npz"
)

shutil.copy2(source_path, drive_path)

print(f"Sačuvano: {drive_path}")
print(f"Veličina: {drive_path.stat().st_size / 1024**2:.1f} MB")
# Out:
# Mounted at /content/drive
# Sačuvano: /content/drive/MyDrive/qwen3_embedding_0_6b_records.npz
# Veličina: 29.7 MB
