# %%
python scripts/generate_embeddings.py \
  --input data/processed/sec2md_structure_v3/embedding_records.jsonl \
  --output data/processed/sec2md_structure_v3/qwen3_embedding_0_6b_v3.npz \
  --checkpoint-dir data/processed/sec2md_structure_v3/qwen3_checkpoints \
  --batch-size 8 \
  --max-seq-length 1024
# Out:
#   File "/tmp/ipykernel_1403/2199029145.py", line 1
#     python scripts/generate_embeddings.py \
#            ^
# SyntaxError: invalid syntax
